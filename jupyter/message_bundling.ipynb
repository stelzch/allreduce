# %%
def parent(idx):
    return idx & (idx - 1)

def largestChild(idx):
    return idx | (idx - 1)

def calcStartIndices(n_summands):
    idx = 0
    result = list()
    for n in n_summands:
        result.append(idx)
        idx += n
    return result

def rankFromIndex(idx, startIndices):
    guard = [(len(startIndices), 1)]
    offset = [(rank, startIdx - idx) for rank, startIdx in enumerate(startIndices)] + guard
    # find first positive valued offset
    offset_is_positive = lambda rank_offset_tuple: rank_offset_tuple[1] > 0
    rank = next(filter(offset_is_positive, offset))[0]
    return rank - 1


"""
Given a list of summands that are assigned to each rank, how many partial sums must be sent out to another rank.
"""
def rankIntersectingNumbers(n_summands, startIndices):
    n_parts = sum(n_summands)
    is_rank_intersecting = lambda idx: rankFromIndex(idx, startIndices) != rankFromIndex(parent(idx), startIndices)
    
    rank_intersecting_summands = filter(is_rank_intersecting, range(0, n_parts))
    return list(rank_intersecting_summands)

def rankIntersectionCount(n_summands, startIndices):
    is_rank_intersecting = lambda startIndex, idx: parent(idx) < startIndex
    # calculate a boolean list of rank intersecting numbers for each rank
    rankIntersectingFlagsPerRank = map(lambda t:
           [is_rank_intersecting(t[0], i) for i in range(t[0], t[0] + t[1])], zip(startIndices, n_summands))
    
    countTrueValues = lambda x: reduce(lambda acc, flag: acc + 1 if flag else acc, x, 0)
    return sum(map(countTrueValues, rankIntersectingFlagsPerRank))

# %%
dataSize = {
    "multi100": 767,
    "dna_rokasD1": 1327505,
    "aa_rokasA8": 504850,
    "fusob": 1602,
    "dna_PeteD8": 3011099,
    "dna_rokasD4": 239763,
    "aa_rokasA4": 1806035,
    "354": 460,
    "prim": 898
}
ranks = 80

# %%
def messageBundling(ranks, totalParts):
    nPerRank = totalParts // ranks
    remainder = totalParts % ranks
    n_summands = [nPerRank + 1 for _ in range(remainder)] + [nPerRank for _ in range(ranks - remainder)]
    assert(len(n_summands) == ranks)
    assert(sum(n_summands) == totalParts)
    print(n_summands)
    startIndices = calcStartIndices(n_summands)
    
    ri_results = rankIntersectingNumbers(n_summands, startIndices)
    prev_rank = 0
    for ri in ri_results:
        rank = rankFromIndex(ri, startIndices)
        if rank != prev_rank:
            print("=" * 80)
            prev_rank = rank
        target = rankFromIndex(parent(ri), startIndices)
        computationalEffort = largestChild(ri) + 1 - ri
        print(f"Rank {rank:3}: {ri:5}, target: {target:3}, effort: {computationalEffort:5}")

# %%
messageBundling(ranks, dataSize["fusob"])
# Out:
# [21, 21, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# ================================================================================
# Rank   1:    21, target:   0, effort:     1
# Rank   1:    22, target:   0, effort:     2
# Rank   1:    24, target:   0, effort:     8
# Rank   1:    32, target:   0, effort:    32
# ================================================================================
# Rank   2:    42, target:   1, effort:     2
# Rank   2:    44, target:   1, effort:     4
# Rank   2:    48, target:   1, effort:    16
# ================================================================================
# Rank   3:    62, target:   2, effort:     2
# Rank   3:    64, target:   0, effort:    64
# ================================================================================
# Rank   4:    82, target:   3, effort:     2
# Rank   4:    84, target:   3, effort:     4
# Rank   4:    88, target:   3, effort:     8
# Rank   4:    96, target:   3, effort:    32
# ================================================================================
# Rank   5:   102, target:   4, effort:     2
# Rank   5:   104, target:   4, effort:     8
# Rank   5:   112, target:   4, effort:    16
# ================================================================================
# Rank   6:   122, target:   5, effort:     2
# Rank   6:   124, target:   5, effort:     4
# Rank   6:   128, target:   0, effort:   128
# ================================================================================
# Rank   7:   142, target:   6, effort:     2
# Rank   7:   144, target:   6, effort:    16
# Rank   7:   160, target:   6, effort:    32
# ================================================================================
# Rank   8:   162, target:   7, effort:     2
# Rank   8:   164, target:   7, effort:     4
# Rank   8:   168, target:   7, effort:     8
# Rank   8:   176, target:   7, effort:    16
# ================================================================================
# Rank   9:   182, target:   8, effort:     2
# Rank   9:   184, target:   8, effort:     8
# Rank   9:   192, target:   6, effort:    64
# ================================================================================
# Rank  10:   202, target:   9, effort:     2
# Rank  10:   204, target:   9, effort:     4
# Rank  10:   208, target:   9, effort:    16
# ================================================================================
# Rank  11:   222, target:  10, effort:     2
# Rank  11:   224, target:   9, effort:    32
# ================================================================================
# Rank  12:   242, target:  11, effort:     2
# Rank  12:   244, target:  11, effort:     4
# Rank  12:   248, target:  11, effort:     8
# Rank  12:   256, target:   0, effort:   256
# ================================================================================
# Rank  13:   262, target:  12, effort:     2
# Rank  13:   264, target:  12, effort:     8
# Rank  13:   272, target:  12, effort:    16
# ================================================================================
# Rank  14:   282, target:  13, effort:     2
# Rank  14:   284, target:  13, effort:     4
# Rank  14:   288, target:  12, effort:    32
# ================================================================================
# Rank  15:   302, target:  14, effort:     2
# Rank  15:   304, target:  14, effort:    16
# Rank  15:   320, target:  12, effort:    64
# ================================================================================
# Rank  16:   322, target:  15, effort:     2
# Rank  16:   324, target:  15, effort:     4
# Rank  16:   328, target:  15, effort:     8
# Rank  16:   336, target:  15, effort:    16
# ================================================================================
# Rank  17:   342, target:  16, effort:     2
# Rank  17:   344, target:  16, effort:     8
# Rank  17:   352, target:  15, effort:    32
# ================================================================================
# Rank  18:   362, target:  17, effort:     2
# Rank  18:   364, target:  17, effort:     4
# Rank  18:   368, target:  17, effort:    16
# ================================================================================
# Rank  19:   382, target:  18, effort:     2
# Rank  19:   384, target:  12, effort:   128
# ================================================================================
# Rank  20:   402, target:  19, effort:     2
# Rank  20:   404, target:  19, effort:     4
# Rank  20:   408, target:  19, effort:     8
# Rank  20:   416, target:  19, effort:    32
# ================================================================================
# Rank  21:   422, target:  20, effort:     2
# Rank  21:   424, target:  20, effort:     8
# Rank  21:   432, target:  20, effort:    16
# ================================================================================
# Rank  22:   442, target:  21, effort:     2
# Rank  22:   444, target:  21, effort:     4
# Rank  22:   448, target:  19, effort:    64
# ================================================================================
# Rank  23:   462, target:  22, effort:     2
# Rank  23:   464, target:  22, effort:    16
# Rank  23:   480, target:  22, effort:    32
# ================================================================================
# Rank  24:   482, target:  23, effort:     2
# Rank  24:   484, target:  23, effort:     4
# Rank  24:   488, target:  23, effort:     8
# Rank  24:   496, target:  23, effort:    16
# ================================================================================
# Rank  25:   502, target:  24, effort:     2
# Rank  25:   504, target:  24, effort:     8
# Rank  25:   512, target:   0, effort:   512
# ================================================================================
# Rank  26:   522, target:  25, effort:     2
# Rank  26:   524, target:  25, effort:     4
# Rank  26:   528, target:  25, effort:    16
# ================================================================================
# Rank  27:   542, target:  26, effort:     2
# Rank  27:   544, target:  25, effort:    32
# ================================================================================
# Rank  28:   562, target:  27, effort:     2
# Rank  28:   564, target:  27, effort:     4
# Rank  28:   568, target:  27, effort:     8
# Rank  28:   576, target:  25, effort:    64
# ================================================================================
# Rank  29:   582, target:  28, effort:     2
# Rank  29:   584, target:  28, effort:     8
# Rank  29:   592, target:  28, effort:    16
# ================================================================================
# Rank  30:   602, target:  29, effort:     2
# Rank  30:   604, target:  29, effort:     4
# Rank  30:   608, target:  28, effort:    32
# ================================================================================
# Rank  31:   622, target:  30, effort:     2
# Rank  31:   624, target:  30, effort:    16
# Rank  31:   640, target:  25, effort:   128
# ================================================================================
# Rank  32:   642, target:  31, effort:     2
# Rank  32:   644, target:  31, effort:     4
# Rank  32:   648, target:  31, effort:     8
# Rank  32:   656, target:  31, effort:    16
# ================================================================================
# Rank  33:   662, target:  32, effort:     2
# Rank  33:   664, target:  32, effort:     8
# Rank  33:   672, target:  31, effort:    32
# ================================================================================
# Rank  34:   682, target:  33, effort:     2
# Rank  34:   684, target:  33, effort:     4
# Rank  34:   688, target:  33, effort:    16
# ================================================================================
# Rank  35:   702, target:  34, effort:     2
# Rank  35:   704, target:  31, effort:    64
# ================================================================================
# Rank  36:   722, target:  35, effort:     2
# Rank  36:   724, target:  35, effort:     4
# Rank  36:   728, target:  35, effort:     8
# Rank  36:   736, target:  35, effort:    32
# ================================================================================
# Rank  37:   742, target:  36, effort:     2
# Rank  37:   744, target:  36, effort:     8
# Rank  37:   752, target:  36, effort:    16
# ================================================================================
# Rank  38:   762, target:  37, effort:     2
# Rank  38:   764, target:  37, effort:     4
# Rank  38:   768, target:  25, effort:   256
# ================================================================================
# Rank  39:   782, target:  38, effort:     2
# Rank  39:   784, target:  38, effort:    16
# Rank  39:   800, target:  38, effort:    32
# ================================================================================
# Rank  40:   802, target:  39, effort:     2
# Rank  40:   804, target:  39, effort:     4
# Rank  40:   808, target:  39, effort:     8
# Rank  40:   816, target:  39, effort:    16
# ================================================================================
# Rank  41:   822, target:  40, effort:     2
# Rank  41:   824, target:  40, effort:     8
# Rank  41:   832, target:  38, effort:    64
# ================================================================================
# Rank  42:   842, target:  41, effort:     2
# Rank  42:   844, target:  41, effort:     4
# Rank  42:   848, target:  41, effort:    16
# ================================================================================
# Rank  43:   862, target:  42, effort:     2
# Rank  43:   864, target:  41, effort:    32
# ================================================================================
# Rank  44:   882, target:  43, effort:     2
# Rank  44:   884, target:  43, effort:     4
# Rank  44:   888, target:  43, effort:     8
# Rank  44:   896, target:  38, effort:   128
# ================================================================================
# Rank  45:   902, target:  44, effort:     2
# Rank  45:   904, target:  44, effort:     8
# Rank  45:   912, target:  44, effort:    16
# ================================================================================
# Rank  46:   922, target:  45, effort:     2
# Rank  46:   924, target:  45, effort:     4
# Rank  46:   928, target:  44, effort:    32
# ================================================================================
# Rank  47:   942, target:  46, effort:     2
# Rank  47:   944, target:  46, effort:    16
# Rank  47:   960, target:  44, effort:    64
# ================================================================================
# Rank  48:   962, target:  47, effort:     2
# Rank  48:   964, target:  47, effort:     4
# Rank  48:   968, target:  47, effort:     8
# Rank  48:   976, target:  47, effort:    16
# ================================================================================
# Rank  49:   982, target:  48, effort:     2
# Rank  49:   984, target:  48, effort:     8
# Rank  49:   992, target:  47, effort:    32
# ================================================================================
# Rank  50:  1002, target:  49, effort:     2
# Rank  50:  1004, target:  49, effort:     4
# Rank  50:  1008, target:  49, effort:    16
# ================================================================================
# Rank  51:  1022, target:  50, effort:     2
# Rank  51:  1024, target:   0, effort:  1024
# ================================================================================
# Rank  52:  1042, target:  51, effort:     2
# Rank  52:  1044, target:  51, effort:     4
# Rank  52:  1048, target:  51, effort:     8
# Rank  52:  1056, target:  51, effort:    32
# ================================================================================
# Rank  53:  1062, target:  52, effort:     2
# Rank  53:  1064, target:  52, effort:     8
# Rank  53:  1072, target:  52, effort:    16
# ================================================================================
# Rank  54:  1082, target:  53, effort:     2
# Rank  54:  1084, target:  53, effort:     4
# Rank  54:  1088, target:  51, effort:    64
# ================================================================================
# Rank  55:  1102, target:  54, effort:     2
# Rank  55:  1104, target:  54, effort:    16
# Rank  55:  1120, target:  54, effort:    32
# ================================================================================
# Rank  56:  1122, target:  55, effort:     2
# Rank  56:  1124, target:  55, effort:     4
# Rank  56:  1128, target:  55, effort:     8
# Rank  56:  1136, target:  55, effort:    16
# ================================================================================
# Rank  57:  1142, target:  56, effort:     2
# Rank  57:  1144, target:  56, effort:     8
# Rank  57:  1152, target:  51, effort:   128
# ================================================================================
# Rank  58:  1162, target:  57, effort:     2
# Rank  58:  1164, target:  57, effort:     4
# Rank  58:  1168, target:  57, effort:    16
# ================================================================================
# Rank  59:  1182, target:  58, effort:     2
# Rank  59:  1184, target:  57, effort:    32
# ================================================================================
# Rank  60:  1202, target:  59, effort:     2
# Rank  60:  1204, target:  59, effort:     4
# Rank  60:  1208, target:  59, effort:     8
# Rank  60:  1216, target:  57, effort:    64
# ================================================================================
# Rank  61:  1222, target:  60, effort:     2
# Rank  61:  1224, target:  60, effort:     8
# Rank  61:  1232, target:  60, effort:    16
# ================================================================================
# Rank  62:  1242, target:  61, effort:     2
# Rank  62:  1244, target:  61, effort:     4
# Rank  62:  1248, target:  60, effort:    32
# ================================================================================
# Rank  63:  1262, target:  62, effort:     2
# Rank  63:  1264, target:  62, effort:    16
# Rank  63:  1280, target:  51, effort:   256
# ================================================================================
# Rank  64:  1282, target:  63, effort:     2
# Rank  64:  1284, target:  63, effort:     4
# Rank  64:  1288, target:  63, effort:     8
# Rank  64:  1296, target:  63, effort:    16
# ================================================================================
# Rank  65:  1302, target:  64, effort:     2
# Rank  65:  1304, target:  64, effort:     8
# Rank  65:  1312, target:  63, effort:    32
# ================================================================================
# Rank  66:  1322, target:  65, effort:     2
# Rank  66:  1324, target:  65, effort:     4
# Rank  66:  1328, target:  65, effort:    16
# ================================================================================
# Rank  67:  1342, target:  66, effort:     2
# Rank  67:  1344, target:  63, effort:    64
# ================================================================================
# Rank  68:  1362, target:  67, effort:     2
# Rank  68:  1364, target:  67, effort:     4
# Rank  68:  1368, target:  67, effort:     8
# Rank  68:  1376, target:  67, effort:    32
# ================================================================================
# Rank  69:  1382, target:  68, effort:     2
# Rank  69:  1384, target:  68, effort:     8
# Rank  69:  1392, target:  68, effort:    16
# ================================================================================
# Rank  70:  1402, target:  69, effort:     2
# Rank  70:  1404, target:  69, effort:     4
# Rank  70:  1408, target:  63, effort:   128
# ================================================================================
# Rank  71:  1422, target:  70, effort:     2
# Rank  71:  1424, target:  70, effort:    16
# Rank  71:  1440, target:  70, effort:    32
# ================================================================================
# Rank  72:  1442, target:  71, effort:     2
# Rank  72:  1444, target:  71, effort:     4
# Rank  72:  1448, target:  71, effort:     8
# Rank  72:  1456, target:  71, effort:    16
# ================================================================================
# Rank  73:  1462, target:  72, effort:     2
# Rank  73:  1464, target:  72, effort:     8
# Rank  73:  1472, target:  70, effort:    64
# ================================================================================
# Rank  74:  1482, target:  73, effort:     2
# Rank  74:  1484, target:  73, effort:     4
# Rank  74:  1488, target:  73, effort:    16
# ================================================================================
# Rank  75:  1502, target:  74, effort:     2
# Rank  75:  1504, target:  73, effort:    32
# ================================================================================
# Rank  76:  1522, target:  75, effort:     2
# Rank  76:  1524, target:  75, effort:     4
# Rank  76:  1528, target:  75, effort:     8
# Rank  76:  1536, target:  51, effort:   512
# ================================================================================
# Rank  77:  1542, target:  76, effort:     2
# Rank  77:  1544, target:  76, effort:     8
# Rank  77:  1552, target:  76, effort:    16
# ================================================================================
# Rank  78:  1562, target:  77, effort:     2
# Rank  78:  1564, target:  77, effort:     4
# Rank  78:  1568, target:  76, effort:    32
# ================================================================================
# Rank  79:  1582, target:  78, effort:     2
# Rank  79:  1584, target:  78, effort:    16
# Rank  79:  1600, target:  76, effort:    64
